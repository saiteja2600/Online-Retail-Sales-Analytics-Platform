-- %%
USE CATALOG onlineretail;

create catalog if not exists onlineretail;

create schema if not exists onlineretail.onlineretail_schema;

GRANT USE CATALOG ON CATALOG onlineretail 
TO `sait38458_gmail.com#ext#@sait38458gmail.onmicrosoft.com`;

GRANT CREATE SCHEMA ON CATALOG onlineretail 
TO `sait38458_gmail.com#ext#@sait38458gmail.onmicrosoft.com`;

GRANT USE SCHEMA ON SCHEMA onlineretail.onlineretail_schema
TO `sait38458_gmail.com#ext#@sait38458gmail.onmicrosoft.com`;

GRANT CREATE TABLE ON SCHEMA onlineretail.onlineretail_schema
TO `sait38458_gmail.com#ext#@sait38458gmail.onmicrosoft.com`;

create table if not exists onlineretail.onlineretail_schema.product_sales;

create table if not exists onlineretail.onlineretail_schema.monthly_sales ;

GRANT SELECT ON TABLE onlineretail.onlineretail_schema.product_sales
TO `sait38458_gmail.com#ext#@sait38458gmail.onmicrosoft.com`;


GRANT SELECT ON TABLE onlineretail.onlineretail_schema.monthly_sales
TO `sait38458_gmail.com#ext#@sait38458gmail.onmicrosoft.com`;

drop table if exists onlineretail.onlineretail_schema.product_sales;

drop table if exists onlineretail.onlineretail_schema.monthly_sales;

GRANT CREATE VIEW 
ON SCHEMA onlineretail.onlineretail_schema
TO `sait38
GRANT CREATE MATERIALIZED VIEW 
ON SCHEMA onlineretail.onlineretail_schema
TO `sait38458_gmail.com#ext#@sait38458gmail.onmicrosoft.com`;


GRANT ALL PRIVILEGES ON CATALOG onlineretail 
TO `sait38458_gmail.com#ext#@sait38458gmail.onmicrosoft.com`;

CREATE SCHEMA IF NOT EXISTS onlineretail.bronze;

CREATE TABLE IF NOT EXISTS onlineretail.bronze.onlinesales;

drop SCHEMA if exists onlineretail.bronze;
SHOW CATALOGS;

SHOW GRANTS ON CATALOG onlineretail;

SHOW SCHEMAS IN onlineretail;

SHOW GRANTS ON SCHEMA onlineretail.onlineretail_schema;
